# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv('WineQT.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality  Id
# 0      9.4        5   0
# 1      9.8        5   1
# ...

# %%
df.shape
# Out:
# (1143, 13)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Data columns (total 13 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   fixed acidity         1143 non-null   float64
#  1   volatile acidity      1143 non-null   float64
#  2   citric acid           1143 non-null   float64
#  3   residual sugar        1143 non-null   float64
#  4   chlorides             1143 non-null   float64
#  5   free sulfur dioxide   1143 non-null   float64
#  6   total sulfur dioxide  1143 non-null   float64
#  7   density               1143 non-null   float64
#  8   pH                    1143 non-null   float64
#  9   sulphates             1143 non-null   float64
#  10  alcohol               1143 non-null   float64
#  11  quality               1143 non-null   int64
#  12  Id                    1143 non-null   int64
# dtypes: float64(11), int64(2)
# memory usage: 116.2 KB

# %%
df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# Id                      0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.drop('Id',axis=1, inplace=True)

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
df.shape
# Out:
# (1143, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1143.000000       1143.000000  1143.000000     1143.000000
# mean        8.311111          0.531339     0.268364        2.532152
# std         1.747595          0.179633     0.196686        1.355917
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.392500     0.090000        1.900000
# 50%         7.900000          0.520000     0.250000        2.200000
# 75%         9.100000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1143.000000          1143.000000           1143.000000  1143.000000
# mean      0.086933            15.615486             45.914698     0.996730
# std       0.047267            10.250486             32.782130     0.001925
# ...

# %%
sns.scatterplot(df['quality'].value_counts())
# Out:
# <Axes: xlabel='quality', ylabel='count'>

# %%
sns.boxplot(df['quality'])
# Out:
# <Axes: ylabel='quality'>

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
df.corr()
# Out:
#                       fixed acidity  volatile acidity  citric acid  \
# fixed acidity              1.000000         -0.250728     0.673157
# volatile acidity          -0.250728          1.000000    -0.544187
# citric acid                0.673157         -0.544187     1.000000
# residual sugar             0.171831         -0.005751     0.175815
# chlorides                  0.107889          0.056336     0.245312
# free sulfur dioxide       -0.164831         -0.001962    -0.057589
# total sulfur dioxide      -0.110628          0.077748     0.036871
# density                    0.681501          0.016512     0.375243
# pH                        -0.685163          0.221492    -0.546339
# sulphates                  0.174592         -0.276079     0.331232
# alcohol                   -0.075055         -0.203909     0.106250
# quality                    0.121970         -0.407394     0.240821
#
#                       residual sugar  chlorides  free sulfur dioxide  \
# ...

# %%
plt.figure(figsize=(12,6))
sns.heatmap(df.corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %%
sns.boxplot(data=df, y='volatile acidity', x='quality')
# Out:
# <Axes: xlabel='quality', ylabel='volatile acidity'>

# %%
sns.boxplot(data=df, y='fixed acidity', x='quality')
# Out:
# <Axes: xlabel='quality', ylabel='fixed acidity'>

# %%
df['Total Acidity'] = df['volatile acidity'] + df['fixed acidity']

# %%
sns.boxplot(data=df, x='quality', y='Total Acidity')
# Out:
# <Axes: xlabel='quality', ylabel='Total Acidity'>

# %%
sns.boxplot(data=df, x='quality', y='Total Acidity')
# Out:
# <Axes: xlabel='quality', ylabel='Total Acidity'>

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3])

# %%
X = df.drop('quality', axis=1)
y = df['quality']

# %%
from sklearn.model_selection import train_test_split
X_train,  X_test,y_train,  y_test = train_test_split(X, y , test_size=0.20, random_state=42)

# %%
X_train.shape, X_test.shape
# Out:
# ((914, 12), (229, 12))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()

# %%
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Support Vector Classifier

# %%
from sklearn.svm import SVC
svc = SVC(kernel='rbf')
svc.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred_train = svc.predict(X_train)

# %%
y_pred = svc.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
print(accuracy_score(y_test, y_pred))
# Out:
# [[ 0  3  3  0  0]
#  [ 0 71 25  0  0]
#  [ 0 25 69  5  0]
#  [ 0  0 19  7  0]
#  [ 0  0  1  1  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.72      0.74      0.73        96
#            6       0.59      0.70      0.64        99
#            7       0.54      0.27      0.36        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.64       229
#    macro avg       0.37      0.34      0.35       229
# weighted avg       0.62      0.64      0.62       229
#
# 0.6419213973799127
# c:\Users\abhap\OneDrive\Documents\ML-(Python)\Lectures Practice ML\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %%
print(confusion_matrix(y_train, y_pred_train))
print(classification_report(y_train, y_pred_train))
print(accuracy_score(y_train, y_pred_train))
# Out:
# [[  0   0   5   1   0   0]
#  [  0   1  19   6   1   0]
#  [  0   0 308  77   2   0]
#  [  0   0  92 258  13   0]
#  [  0   0   6  65  46   0]
#  [  0   0   1   9   4   0]]
#               precision    recall  f1-score   support
#
#            3       0.00      0.00      0.00         6
#            4       1.00      0.04      0.07        27
#            5       0.71      0.80      0.75       387
#            6       0.62      0.71      0.66       363
#            7       0.70      0.39      0.50       117
#            8       0.00      0.00      0.00        14
#
#     accuracy                           0.67       914
#    macro avg       0.51      0.32      0.33       914
# weighted avg       0.67      0.67      0.65       914
#
# 0.6706783369803063
# ...

# %%
from sklearn.model_selection import GridSearchCV
param = {
    'C': [0.1, 1, 10, 100],
    'kernel': ['rbf', 'linear'],
    'gamma': ['scale', 'auto']
}

# %%
grid = GridSearchCV(SVC(), param_grid=param, refit=True, cv=5, verbose=3)

# %%
grid.fit(X_train, y_train)
y_pred_grid = grid.predict(X_test)
# Out:
# Fitting 5 folds for each of 16 candidates, totalling 80 fits
# [CV 1/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.596 total time=   0.0s
# [CV 2/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.612 total time=   0.0s
# [CV 3/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.563 total time=   0.0s
# [CV 4/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.590 total time=   0.0s
# [CV 5/5] END ....C=0.1, gamma=scale, kernel=rbf;, score=0.588 total time=   0.0s
# [CV 1/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.563 total time=   0.0s
# [CV 2/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.585 total time=   0.0s
# [CV 3/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.563 total time=   0.0s
# [CV 4/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.596 total time=   0.0s
# [CV 5/5] END .C=0.1, gamma=scale, kernel=linear;, score=0.560 total time=   0.0s
# [CV 1/5] END .....C=0.1, gamma=auto, kernel=rbf;, score=0.596 total time=   0.0s
# ...

# %%
print(confusion_matrix(y_test, y_pred_grid))
print(classification_report(y_test, y_pred_grid))
print(accuracy_score(y_test, y_pred_grid))
# Out:
# [[ 0  3  3  0  0]
#  [ 0 71 25  0  0]
#  [ 0 25 69  5  0]
#  [ 0  0 19  7  0]
#  [ 0  0  1  1  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.72      0.74      0.73        96
#            6       0.59      0.70      0.64        99
#            7       0.54      0.27      0.36        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.64       229
#    macro avg       0.37      0.34      0.35       229
# weighted avg       0.62      0.64      0.62       229
#
# 0.6419213973799127
# c:\Users\abhap\OneDrive\Documents\ML-(Python)\Lectures Practice ML\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rf = RandomForestClassifier()
rf.fit(X_train, y_train)

y_pred_rf = rf.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
print(accuracy_score(y_test, y_pred_rf))
# Out:
# [[ 0  3  3  0  0]
#  [ 0 76 19  1  0]
#  [ 0 29 63  7  0]
#  [ 0  0 11 15  0]
#  [ 0  0  2  0  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.70      0.79      0.75        96
#            6       0.64      0.64      0.64        99
#            7       0.65      0.58      0.61        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.67       229
#    macro avg       0.40      0.40      0.40       229
# weighted avg       0.65      0.67      0.66       229
#
# 0.6724890829694323
# c:\Users\abhap\OneDrive\Documents\ML-(Python)\Lectures Practice ML\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Stochastic Gradient Descent

# %%
from sklearn.linear_model import SGDClassifier
sgd = SGDClassifier(loss='hinge', max_iter=1000, tol=1e-3, random_state=42)
sgd.fit(X_train, y_train)

y_pred_sgd = sgd.predict(X_test)

# %%
print(confusion_matrix(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
print(accuracy_score(y_test, y_pred_rf))
# Out:
# [[ 0  3  3  0  0]
#  [ 0 76 19  1  0]
#  [ 0 29 63  7  0]
#  [ 0  0 11 15  0]
#  [ 0  0  2  0  0]]
#               precision    recall  f1-score   support
#
#            4       0.00      0.00      0.00         6
#            5       0.70      0.79      0.75        96
#            6       0.64      0.64      0.64        99
#            7       0.65      0.58      0.61        26
#            8       0.00      0.00      0.00         2
#
#     accuracy                           0.67       229
#    macro avg       0.40      0.40      0.40       229
# weighted avg       0.65      0.67      0.66       229
#
# 0.6724890829694323
# c:\Users\abhap\OneDrive\Documents\ML-(Python)\Lectures Practice ML\venv\Lib\site-packages\sklearn\metrics\_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
# ...

# %% [markdown]
# ## Comparison

# %%
models = ['SVC', 'Random', 'SDG']
accuracy = [0.64, 0.67, 0.67]

plt.bar(models, accuracy, color=['green', 'orange', 'blue'])
plt.ylabel('Test Accuracy')
plt.title('Model Comparison on Wine Quality Dataset')
plt.ylim(0,1)
plt.show()

# %% [markdown]
# ## Conclusion
#
# Best Model (Test Accuracy): Random Forest and SGDClassifier (~67%)
#
# Random Forest is robust and handles feature interactions well.
#
# SGDClassifier is simple and fast but sensitive to scaling and hyperparameters.
#
# SVC might be underperforming due to multi-class nature and limited hyperparameter tuning.
#
#
#
# Usually, features like:
#
# alcohol
#
# sulphates
#
# volatile acidity
#
# density
#
# ...tend to be the most influential in wine quality prediction.
